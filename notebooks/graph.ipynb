# %%
# Connect to postgis using geopandas
import geopandas as gpd
import psycopg2

con = psycopg2.connect(database="graph", user="postgres", host="localhost")

# %%
sql = "select * from route"
routes = gpd.read_postgis(sql, con, geom_col='geom', index_col='gid')
